# %%
import csv
import matplotlib.pyplot as plt 
f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []  #최고 기온 값을 저장할 리스트 high 생성
low = [] #최저 기온 값을 저장할 리스트 low 생성

for row in data:
    if row[-1] != '' and row[-2] !='':  # 최고 기온 값고 최저 기온 값이 존재한다면
        if 1997 <= int(row[0].split('-')[0]) : # 1997년 이후 데이터라면
            if row[0].split('-')[1]=='10' and row[0].split('-')[2]=='15' : #10월 15일 이라면
                high.append(float(row[-1])) #최고 기온 값을 high 리스트에 저장
                low.append(float(row[-2])) #최저 기온 값을 low 리스트에 저장

plt.plot(high,'hotpink')  #high 리스트에 저장된 값을 hotpink 색으로 그리기
plt.plot(low,'skyblue') #low 리스트에 저장된 값을 skyblue 색으로 그리기    
plt.rc('font',family = 'Malgun Gothic')
plt.title('내 생일의 기온 변화 그래프')
plt.show()

# %%
s = 'hello python'
print(s.split())
# Out:
# ['hello', 'python']
